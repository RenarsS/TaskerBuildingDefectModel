# %% [markdown]
# # Tasker building defect recognition models
#
# Used YOLOv12.

# %%
import torch
from ultralytics import YOLO

# %%
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("Device count:", torch.cuda.device_count())
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# CUDA version: 11.8
# Device count: 1
# Device name: NVIDIA GeForce GTX 1650

# %%
model = YOLO("yolo12s.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12s.pt to 'yolo12s.pt': 100% ━━━━━━━━━━━━ 18.1MB 44.8MB/s 0.4s0.4s<0.0s

# %%
result =  model.train(
    data="data/data.yaml",
    epochs=20,
    patience=5,
    imgsz=512,
    batch=8,
    workers=2,
    device=0,
    mosaic=0.5,
    mixup=0,
    cache=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.233 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.232  Python-3.12.12 torch-2.5.1 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0, mode=train, model=yolo12s.pt, momentum=0.937, mosaic=0.5, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\renar\Academia\App\TaskerModel\runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 4]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1    345856  ultralytics.nn.modules.block.A2C2f           [768, 256, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     95104  ultralytics.nn.modules.block.A2C2f           [512, 128, 1, False, -1]
#  15                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1    296704  ultralytics.nn.modules.block.A2C2f           [384, 256, 1, False, -1]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  21        [14, 17, 20]  1    821730  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# YOLOv12s summary: 272 layers, 9,255,458 parameters, 9,255,442 gradients
#
# Transferred 685/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# WARNING AMP: checks failed . AMP training on NVIDIA GeForce GTX 1650 GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Fast image access  (ping: 0.00.0 ms, read: 23.713.9 MB/s, size: 25.2 KB)
# train: Scanning C:\Users\renar\Academia\App\TaskerModel\data\train\labels.cache... 2281 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2281/2281 2.3Mit/s 0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 4, len(boxes) = 3083. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (1.7GB RAM): 100% ━━━━━━━━━━━━ 2281/2281 498.0it/s 4.6s<0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 29.111.5 MB/s, size: 18.9 KB)
# val: Scanning C:\Users\renar\Academia\App\TaskerModel\data\valid\labels.cache... 627 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      3.29G      1.238      1.549      1.613          1        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:17<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.7it/s 15.0s0.4s
#                    all        627        865      0.668      0.623      0.651       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      3.31G      1.206      1.458      1.595          1        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:17<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.8it/s 14.1s0.4s
#                    all        627        865      0.656      0.622      0.652      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      3.31G      1.192      1.399      1.598          1        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:15<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.8it/s 14.0s0.4s
#                    all        627        865      0.664      0.609      0.647       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      3.31G      1.157      1.339      1.555          1        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:16<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.9it/s 13.8s0.3s
#                    all        627        865      0.689      0.629      0.676      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      3.29G      1.139      1.292      1.548          1        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:16<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.8it/s 14.1s0.4s
#                    all        627        865      0.684      0.667      0.697       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      3.31G      1.106      1.228      1.514          2        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:17<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.9it/s 14.0s0.4s
#                    all        627        865      0.721      0.662      0.712       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20       3.3G      1.085      1.163      1.503          1        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:15<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.9it/s 14.0s0.4s
#                    all        627        865      0.735      0.669      0.728      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      3.31G      1.066      1.133      1.483          1        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:16<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.8it/s 14.4s0.4s
#                    all        627        865      0.701      0.698      0.742      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      3.29G       1.06      1.084       1.47          1        512: 100% ━━━━━━━━━━━━ 286/286 2.1it/s 2:16<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.9it/s 14.0s0.4s
#                    all        627        865      0.737      0.682      0.745      0.499
#
# 20 epochs completed in 0.864 hours.
# Optimizer stripped from C:\Users\renar\Academia\App\TaskerModel\runs\detect\train\weights\last.pt, 18.9MB
# Optimizer stripped from C:\Users\renar\Academia\App\TaskerModel\runs\detect\train\weights\best.pt, 18.9MB
#
# Validating C:\Users\renar\Academia\App\TaskerModel\runs\detect\train\weights\best.pt...
# Ultralytics 8.3.232  Python-3.12.12 torch-2.5.1 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# YOLOv12s summary (fused): 159 layers, 9,233,202 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 3.0it/s 13.4s0.3s
#                    all        627        865      0.737      0.682      0.745      0.499
#                  algae        108        108      0.897      0.966      0.987      0.765
#            major_crack        113        121      0.706      0.777      0.758      0.553
#            minor_crack        118        134       0.73      0.784      0.789      0.529
#                peeling        102        229      0.742      0.445      0.622      0.363
#               spalling         83         95       0.76      0.666      0.775      0.505
#                  stain        103        178      0.585      0.455      0.538      0.277
# Speed: 0.3ms preprocess, 16.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to C:\Users\renar\Academia\App\TaskerModel\runs\detect\train
